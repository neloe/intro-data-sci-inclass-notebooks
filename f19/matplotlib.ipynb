# %%
import matplotlib.pyplot as plt

# %%
xdata = [1,2,3,4,5,6]
ydata = [1,4,9,16,25,36]

plt.plot(xdata, ydata)

# %%
plt.plot(xdata, ydata, marker='o')

# %%
plt.plot(xdata, ydata, marker='^')

# %%
plt.plot(xdata, ydata, marker='^', color='#006747')

# %%
plt.plot(ydata)

# %%
plt.scatter(xdata, ydata)

# %%
plt.scatter(xdata, ydata, color=['r', 'r', 'c', 'r', 'r', 'r'])

# %%
plt.scatter(xdata, ydata, color=['r', 'r', 'c', 'r', 'r', 'r'], s = 100)

# %%
plt.scatter(xdata, ydata, color=['r', 'r', 'c', 'r', 'r', 'r'], s = [10, 40, 90, 160, 250, 360])

# %%
plt.scatter(xdata, ydata, color=['r', 'r', 'c', 'r', 'r', 'r'], s = [10, 40, 90, 160, 250, 360])

# %%
plt.bar(xdata, ydata)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(xdata, ydata, width=0.5)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(xdata, ydata, width=0.5, tick_label=['a','b','c','d','e','f'])
# Out:
# <BarContainer object of 6 artists>

# %%
ydata2 = [36, 25, 16, 9, 4, 1]

shifted_x = [.8, 1.8, 2.8, 3.8, 4.8, 5.8]
plt.bar(xdata, ydata2, width=0.4, tick_label=['a','b','c','d','e','f'], align='edge')
plt.bar(shifted_x, ydata, width=0.4, color='r')
# Out:
# <BarContainer object of 6 artists>

# %%
plt.barh(xdata, ydata, height=1.5, edgecolor='r')
# Out:
# <BarContainer object of 6 artists>

# %%
import pandas
spotify_data = pandas.read_csv('SpotifyFeatures.csv')

# %%
plt.hist(spotify_data['danceability'])
# Out:
# (array([ 5343., 11159., 15465., 24278., 36831., 45808., 43484., 32052.,
#         15237.,  3068.]),
#  array([0.0569 , 0.15011, 0.24332, 0.33653, 0.42974, 0.52295, 0.61616,
#         0.70937, 0.80258, 0.89579, 0.989  ]),
#  <a list of 10 Patch objects>)

# %%
len(spotify_data)
# Out:
# 232725

# %%
para = 'It was the best of times, it was the worst of times, it was the age of wisdom, it was the age of foolishness, it was the epoch of belief, it was the epoch of incredulity, it was the season of Light, it was the season of Darkness, it was the spring of hope, it was the winter of despair, we had everything before us, we had nothing before us, we were all going direct to Heaven, we were all going direct the other way - in short, the period was so far like the present period, that some of its noisiest authorities insisted on its being received, for good or for evil, in the superlative degree of comparison only.'.lower()

# %%
import nltk
from nltk import word_tokenize
nltk.download('punkt')
words = word_tokenize(para)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\squishy\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
from collections import Counter

word_count = Counter(words)

# %%
print(word_count)
# Out:
# Counter({',': 17, 'the': 14, 'of': 12, 'was': 11, 'it': 10, 'we': 4, 'times': 2, 'age': 2, 'epoch': 2, 'season': 2, 'had': 2, 'before': 2, 'us': 2, 'were': 2, 'all': 2, 'going': 2, 'direct': 2, 'in': 2, 'period': 2, 'its': 2, 'for': 2, 'best': 1, 'worst': 1, 'wisdom': 1, 'foolishness': 1, 'belief': 1, 'incredulity': 1, 'light': 1, 'darkness': 1, 'spring': 1, 'hope': 1, 'winter': 1, 'despair': 1, 'everything': 1, 'nothing': 1, 'to': 1, 'heaven': 1, 'other': 1, 'way': 1, '-': 1, 'short': 1, 'so': 1, 'far': 1, 'like': 1, 'present': 1, 'that': 1, 'some': 1, 'noisiest': 1, 'authorities': 1, 'insisted': 1, 'on': 1, 'being': 1, 'received': 1, 'good': 1, 'or': 1, 'evil': 1, 'superlative': 1, 'degree': 1, 'comparison': 1, 'only': 1, '.': 1})

# %%
labels = []
for word in word_count:
    if word not in [',', '-', '.']:
        labels.append(word)
heights = []
for word in labels:
    heights.append(word_count[word])

# %%
plt.barh(range(len(heights)), heights, tick_label=labels)
# Out:
# <BarContainer object of 58 artists>
